# %% [markdown]
# <a href="https://colab.research.google.com/github/rijuCr7/NLP/blob/master/Assignment_1_Swarnadeep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Swarnadeep Bhar
# MCS201802
# Assignment 1

# %%
# In[01]
#importing packages for usage
import re
import nltk
nltk.download('all')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import os
import string
from urllib import request
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Feb 13 21:37:05 2019

@author: swarnadeep
"""

"""
    Speed as Value = Speed(v)
    Speed as Question = Speed(Q)
    Distance as Value = Distance(V)
    Distance as Question = Distance(Q)
    Time as Value = Time(V)
    Time as Question = Time(Q)
    Acceleration as Value = Acceleration(V)
    Acceleration as Question = Acceleration(Q)
"""
# In[02]
#function to test whether a sentence is a question or not
def isQuestion(sentence):
    flag = False
    question_terms = ["calculate","what","why","when","how","find","determine"]
    if sentence.endswith("?"):
        return True
    else:
        terms = word_tokenize(sentence)
        for term in terms:
            if term.lower() in question_terms:
                flag = True
    return flag
# In[03]
#copied from github,match multiple regular expressions
def replace(expr, substitutions):
    substrings = sorted(substitutions, key=len, reverse=True)
    regex = re.compile('|'.join(map(re.escape, substrings)))
    return regex.sub(lambda match: substitutions[match.group(0)], expr)
# In[04]
#method to standardize speed
def standardizeSpeed(text):
    """convert the units to the standard form as prescribed"""
    substitutions={"metres per second":"l/t",
                   "metres per hour":"l/t",
                   "metres per minute":"l/t",
                   "kilometres per second":"l/t",
                   "kilometres per hour":"l/t",
                   "miles per second":"l/t",
                   "miles per hour":"l/t",
                   "miles per minute":"l/t",
                   "konts":"l/t",
                   "feet per second":"l/t",
                   }
    text = replace(text,substitutions)
    #check for short forms first
    short_form = {"km/hr":"l/t",
                  "km/h":"l/t",
                  "m/s":"l/t",
                  "mi/h":"l/t",
                  "kmh":"l/t"
                  }
    term_list = word_tokenize(text)
    output_length = ""
    for word in term_list:
        if word.lower() in short_form.keys():
            output_length = output_length + " " + short_form[word.lower()]
        else:
            output_length = output_length + " " + word
    #output_length = replace(text,substitutions)
    return output_length
# In[05]
def standardizeTime(text):  
    #convert the time to the standard form
    substitutions={"seconds":"t",
                   "minutes":"t",
                   "hours":"t",
                   "second":"t",
                   "minute":"t",
                   "hour":"t",
                   "s":"t"
                   }
    term_list = word_tokenize(text)
    output_length = ""
    for word in term_list:
        if word.lower() in substitutions.keys():
            output_length = output_length + " " + substitutions[word.lower()]
        else:
            output_length = output_length + " " + word
    #output_length = replace(text,substitutions)
    return output_length
# In[06]
def standardizeLength(text):
    substitutions={"metres":"l",
                   "miles":"l",
                   "degree":"l",
                   "meters":"l",
                   "miles":"l",
                   "kilometres":"l",
                   "centimetres":"l",
                   "ms":"l",
                   "mi":"l",
                   "m":"l",
                   "cms":"l",
                   "kms":"l",
                   "m":"l",
                   "cm":"l",
                   "km":"l",
                   str(chr(176)):"l" #degree symbol
                   }
    term_list = word_tokenize(text)
    output_length = ""
    for word in term_list:
        for punct in string.punctuation:
            if punct != '/':
                word = word.replace(punct,"")
        if word.lower() in substitutions.keys():
            output_length = output_length + " " + substitutions[word.lower()]
        else:
            output_length = output_length + " " + word
    return output_length
# In[07]
def standardizeAcc(text):
    substitutions={"m/s2":" l/t2",
                   "m/s^2":" l/t2"
                   }
    output_length = replace(text,substitutions)
    return output_length
# In[08]
def splitNumbersAndUnits(text):
    term_list = word_tokenize(text)
    #print(term_list)
    new_term = ""
    change_terms = {}
    problem = []
    pos = 0
    for term in term_list:
        if term[0].isdigit():
            #print(term)
            problem.append(term)
    for word in problem:
        for i in range(0,len(word)):
            #print(word[i])
            if not word[i].isdigit():
                pos = i
                #print(pos)
                break
        #print(word[:pos])
        #print(word[pos:])
        new_term = word[:pos] + " " + word[pos:]
        change_terms[word] = new_term
        #print(new_term)
    #print(change_terms)
    new_text = ""
    for term in term_list:
        if term in change_terms.keys():
            new_text = new_text + " " + change_terms[term]
        else:
            new_text = new_text + " " + term
    return new_text
# In[09]
def standardizeText(text):
    #insert accleration standardize here
    accleration = standardizeAcc(text)
    speed = standardizeSpeed(accleration)
    time_speed = standardizeTime(speed)
    length_time_speed =  standardizeLength(time_speed)
    final_standard=""
    tokens = word_tokenize(length_time_speed)
    #checking for spurious units
    for i in range(0,len(tokens)):
        #print(length_time_speed[i])
        if i >= 0:
            if tokens[i] == 'l/t':
                if (i-1) >= 0 and not tokens[i-1].isdigit():
                    #length_time_speed[i] = " "
                    final_standard = final_standard + " "
                else:
                    final_standard = final_standard + " " + tokens[i]
            elif tokens[i] == 'l':
                if (i-1) >= 0 and not tokens[i-1].isdigit():
                    #length_time_speed[i] = " "
                    final_standard = final_standard + " "
                else:
                    final_standard = final_standard + " " + tokens[i]
            elif tokens[i] == 't':
                if (i-1) >= 0 and not tokens[i-1].isdigit():
                    #length_time_speed[i] = " "
                    final_standard = final_standard + " "
                else:
                    final_standard = final_standard + " " + tokens[i]
            elif tokens[i] == 'l/t2':
                if (i-1) >= 0 and not tokens[i-1].isdigit():
                    #length_time_speed[i] = " "
                    final_standard = final_standard + " "
                else:
                    final_standard = final_standard + " " + tokens[i]
            else:
                final_standard = final_standard + " " + tokens[i]
    return final_standard
# In[10]
#creating dictionaries for synomyms 
distance = {'distance':"distance",
            'displacement':"displacement",
            'area':"area",
            'height':"height",
            'far':"far",
            'tall':"tall",
            'length':"length",
            'orbit':"orbit",
            'high':"high",
            'angle':"angle",
            'altitude':"altitude",
            'radius':"radius",
            'scope':"scope",
            'seperation':"seperation",
            'size':"size",
            'stretch':"stretch",
            'width':"width",
            'degreee':"degree",
        }
speed = {'velocity':"velocity",
         'agility':"agility",
         'pace':"pace",
         'quickness':"quickness",
         'swiftness':"swiftnes",
         'speed':"speed",
         'fast':"fast"
         }
time = {'time':"time",
        'long':"long",
        'seconds':"seconds",
        'hang time':"hang time",
        'hangtime':"hangtime",
        'hang-time':"hang-time",
        'in the air':"in the air"
        }

accleration = {'acceleration':"acceleration",
               'deceleration':"deceleration"
               }
# In[11]
#this method is always run after the standardizeText method 
def extractInformation(sentence):
    information = {'Speed(V)':0,
                   'Speed(Q)':0,
                   'Distance(V)':0,
                   'Distance(Q)':0,
                   'Time(V)':0,
                   'Time(Q)':0,
                   'Acceleration(V)':0,
                   'Acceleration(Q)':0
                   }
    term_list = word_tokenize(sentence)
    #print(term_list)
    for word in term_list:
        if word == "l/t":
            #print("Speed as Value")
            information['Speed(V)'] = 1
        if word == "l":
            #print("Distance as Value")
            information['Distance(V)'] = 1
        if word == "t":
            #print("Time as Value")
            information['Time(V)'] = 1
        if word == "l/t2":
            #print("Acceleration as Value")
            information['Acceleration(V)'] = 1                
    for i in range(len(term_list)):
        word = term_list[i]
        if word.lower() in speed.values():
            flag = False
            for j in range(i+1,len(term_list)):
                if "l/t" == term_list[j]:
                    flag = True
                    break
            if flag :
                information['Speed(V)'] = 1
                #print("Speed as Value")
            else:
                information['Speed(Q)'] = 1
                #print("Speed as Question")
        if word.lower() in distance.values():
            flag = False
            punctuation = "!#$%&'()*+,-.:;<=>?@[\]^_`{|}~"
            useless = False
            for j in range(i+1,len(term_list)):
                if "l" == term_list[j]:
                    flag = True
                    break
                elif term_list[j] in punctuation:
                    useless = True
            if flag and not useless:
                information['Distance(V)'] = 1
                #print("Distance as Value")
            else:
                if not useless:
                    information['Distance(Q)'] = 1
                    #print("Distance as Question")
        if word.lower() in time.values():
            flag = False
            for j in range(i+1,len(term_list)):
                if "t" == term_list[j]:
                    flag = True
                    break
            if flag :
                information['Time(V)'] = 1
                #print("Time as Value")
            else:
                information['Time(Q)'] = 1
                #print("Time as Question")
        if word.lower() in accleration.values():
            flag = False
            for j in range(i+1,len(term_list)):
                if "l/t2" == term_list[j]:
                    flag = True
                    break
            if flag :
                information['Acceleration(V)'] = 1
                #print("Accleration as Value")
            else:
                information['Acceleration(Q)'] = 1
                #print("Accleration as Question")
    return information
# In[12]
def is_useless(statement):
    term_list = word_tokenize(statement)
    #print(term_list)
    flag = True
    for word in term_list:
        if word == "l/t":
            flag =  False
            break
        if word == "t":
            flag = False
            break
        if word == "l":
            flag = False
            break
        if word == "l/t2":
            flag = False
            break
    return flag
# In[13]
def eliminateBrackets(problem):
    bracketed=problem[problem.find("(")+1:problem.find(")")]#finding string between 2 brackets
    #if useless then eliminate the bracketed part
    print(is_useless(bracketed))
    if is_useless(bracketed):
        temp_new_problem = problem.replace(bracketed," ")
        new_problem = temp_new_problem.replace("( )"," ")
        return new_problem
    else:
        return problem
# In[14]
def make_index():
    print("Indexing,Please Wait....")
    print("Speed May depend on Internet Connection....")
    index={}
    for i in range(0,271):
        file = 'file'+str(i)+'.txt'
        url="https://www.cmi.ac.in/~koustav/Assignment-1/"+file
        res=request.urlopen(url)
        file_content=res.read()
        text=file_content.decode('utf-8')
        index[file] = extractInformation(standardizeText(splitNumbersAndUnits(text)))
    for key,value in index.items():
        print(key,value)
        print("================")
    print("=================================================")
    print("Showing sample access to a particular vector")
    print("file267.txt")
    print("==================================================")
    print(index['file267.txt'])
    print("==================================================")
# In[15]
make_index()
# Out:
# Indexing,Please Wait....
# Speed May depend on Internet Connection....
# file0.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file1.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file2.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file3.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file4.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file5.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file6.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file7.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 1}
# ================
# file8.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file9.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file10.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file11.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file12.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file13.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file14.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file15.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file16.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file17.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file18.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file19.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file20.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file21.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file22.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file23.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file24.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file25.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file26.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file27.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file28.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file29.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file30.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file31.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file32.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file33.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file34.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file35.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file36.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file37.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file38.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file39.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file40.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file41.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file42.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file43.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file44.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file45.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file46.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file47.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file48.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file49.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file50.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file51.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file52.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file53.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file54.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file55.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file56.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file57.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file58.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file59.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file60.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file61.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file62.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file63.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file64.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file65.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file66.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file67.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file68.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file69.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file70.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file71.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file72.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file73.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file74.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file75.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file76.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file77.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file78.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file79.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file80.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file81.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file82.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file83.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file84.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file85.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file86.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file87.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file88.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file89.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file90.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file91.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file92.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file93.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file94.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file95.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file96.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file97.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file98.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file99.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file100.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file101.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file102.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file103.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file104.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file105.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file106.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file107.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file108.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file109.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file110.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file111.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file112.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file113.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file114.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file115.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file116.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file117.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file118.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file119.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file120.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file121.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file122.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file123.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file124.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file125.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file126.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file127.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file128.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file129.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file130.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file131.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file132.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file133.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file134.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file135.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file136.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file137.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file138.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file139.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file140.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file141.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file142.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file143.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file144.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file145.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file146.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file147.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file148.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file149.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file150.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file151.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file152.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file153.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file154.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file155.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file156.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file157.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file158.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file159.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file160.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file161.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file162.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file163.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file164.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file165.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file166.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file167.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file168.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file169.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file170.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file171.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file172.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file173.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file174.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file175.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file176.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file177.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file178.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file179.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file180.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file181.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file182.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file183.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file184.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file185.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file186.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file187.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file188.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file189.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file190.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file191.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file192.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file193.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file194.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file195.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file196.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file197.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file198.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file199.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file200.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file201.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file202.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file203.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file204.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file205.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file206.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file207.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file208.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file209.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file210.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file211.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file212.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file213.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file214.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file215.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file216.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file217.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file218.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file219.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file220.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file221.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file222.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file223.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file224.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file225.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file226.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file227.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file228.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file229.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file230.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file231.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file232.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file233.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file234.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file235.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file236.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file237.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file238.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file239.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file240.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file241.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file242.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file243.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file244.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file245.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file246.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file247.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file248.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file249.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file250.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file251.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file252.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file253.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file254.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file255.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file256.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file257.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file258.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file259.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file260.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file261.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file262.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file263.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file264.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file265.txt {'Speed(V)': 1, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file266.txt {'Speed(V)': 0, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 1, 'Acceleration(Q)': 0}
# ================
# file267.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file268.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 1}
# ================
# file269.txt {'Speed(V)': 1, 'Speed(Q)': 0, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 0, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# file270.txt {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 0, 'Distance(Q)': 1, 'Time(V)': 1, 'Time(Q)': 0, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ================
# =================================================
# Showing sample access to a particular vector
# file267.txt
# ==================================================
# {'Speed(V)': 0, 'Speed(Q)': 1, 'Distance(V)': 1, 'Distance(Q)': 0, 'Time(V)': 0, 'Time(Q)': 1, 'Acceleration(V)': 0, 'Acceleration(Q)': 0}
# ==================================================
